# %% [markdown]
# # Comparing Sources: MediaCloud Collections vs. Local News Initiative

# %%
import pandas as pd
import requests
import mcmetadata
import os

# %%
def clean_url(url):
    url = url.replace('https://', '').replace('http://', '')
    if url.startswith('www.'):
        url = url[4:]
    url = url.rstrip('/')
    return url

# %%
def download_file_from_google_drive(file_id, output_filename):
    url = f"https://drive.google.com/uc?id={file_id}"
    response = requests.get(url, stream=True)

    if response.status_code == 200:
        with open(output_filename, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"File downloaded successfully as {output_filename}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

# %% [markdown]
# ### Download files from Google Drive

# %%
lni_sources_file="tmp/lni_sources.json"
download_file_from_google_drive("1iHHZ6H9er6MICozbC1pCuA-6gTE5SIIm", lni_sources_file)
# Out:
# File downloaded successfully as tmp/lni_sources.json

# %%
# We had to split Mediacloud sources to download them from Google Drive easily
mediacloud_sources_files = [
    "1ED1INjhodMV1jZeFKFMrphjE0K5wR5mE",
    "1ck1uGpr-J4NdwPAr-wnPiU6gGViI_Zfk",
    "1853yFlD-GupaxU6xuG0UJsMFn4w11f0N",
    "1C2BH2HSx30qsQTBZNIO2odEakwSgyCeq",
    "1oTJfWa1meZbEJoIC4EVGh935wv-OpVzb",
]
for index, mediacloud_sources_file in enumerate(mediacloud_sources_files):
    download_file_from_google_drive(mediacloud_sources_file, f"tmp/mediacloud_sources_part_{index}.csv")
# Out:
# File downloaded successfully as tmp/mediacloud_sources_part_0.csv
# File downloaded successfully as tmp/mediacloud_sources_part_1.csv
# File downloaded successfully as tmp/mediacloud_sources_part_2.csv
# File downloaded successfully as tmp/mediacloud_sources_part_3.csv
# File downloaded successfully as tmp/mediacloud_sources_part_4.csv

# %% [markdown]
# ### Read the downloaded files

# %%
lni_df = pd.read_json(lni_sources_file)

# %%
dataframes = []
for i in range(5):
    file = f"tmp/mediacloud_sources_part_{i}.csv"
    print("Reading "+file)
    if os.path.exists(file):
        df = pd.read_csv(file)
        dataframes.append(df)
    else:
        print(f"File not found: {file}")
mediacloud_df = pd.concat(dataframes, ignore_index=True)
# Out:
# Reading tmp/mediacloud_sources_part_0.csv
# Reading tmp/mediacloud_sources_part_1.csv
# Reading tmp/mediacloud_sources_part_2.csv
# Reading tmp/mediacloud_sources_part_3.csv
# Reading tmp/mediacloud_sources_part_4.csv

# %% [markdown]
# ### Get sources that were scraped from `The Local News Initiative` but not present in MediaCloud directory by using Canonical Domain

# %% [markdown]
# #### Add canonical_domain and clean_url fields to the LNI dataset that will be used for comparison with MediaCloud sources

# %%
lni_df["canonical_domain"] = lni_df["url"].apply(mcmetadata.urls.canonical_domain)
lni_df["clean_url"] = lni_df["url"].apply(clean_url)

# %%
lni_df.head()
# Out:
#    id state      county                  media_name media_type  year_loaded  \
# 0   1    VA  Washington  ADJ Bristol Herald Courier  Newspaper         2024
# 1   2    VA     Augusta         ADJ The News Leader  Newspaper         2024
# 2   3    VA     Augusta      ADJ Augusta Free Press  Newspaper         2024
# 3   4    NC     Madison    News-Record and Sentinel  Newspaper         2024
# 4   5    WI        Wood     Marshfield News-Herald   Newspaper         2024
#
#     fips                                                url  \
# 0  51191                                  heraldcourier.com
# 1  51015                                 www.newsleader.com
# 2  51015  augustafreepress.com/news/sheriff-20k-in-coins...
# 3  37115  www.citizen-times.com/local/news-record-and-se...
# 4  55141                       www.marshfieldnewsherald.com
#
#            canonical_domain                                          clean_url
# 0         heraldcourier.com                                  heraldcourier.com
# 1            newsleader.com                                     newsleader.com
# 2      augustafreepress.com  augustafreepress.com/news/sheriff-20k-in-coins...
# 3         citizen-times.com   citizen-times.com/local/news-record-and-sentinel
# 4  marshfieldnewsherald.com                           marshfieldnewsherald.com

# %% [markdown]
# #### Add clean_url field to MediaCloud sources dataset

# %%
mediacloud_df.loc[:, "clean_url"] = mediacloud_df["homepage"].apply(clean_url)

# %%
mediacloud_df.head(1000)
# Out:
#      source_id                             name  \
# 0      1595389        lyvinthenet.wordpress.com
# 1      1595390  artificialintelligencemania.com
# 2      1595391             jhrogue.blogspot.com
# 3      1595392                     teach-ict.co
# 4      1595393                      bbb2022.com
# ..         ...                              ...
# 995    1596610                  dieseltykes.com
# 996    1596611                measureaustin.org
# 997    1596612                baylaurelfund.com
# 998    1596613                   bearracuda.com
# 999    1596614                candymanmovie.com
#
#                                label                                 homepage  \
# 0          lyvinthenet.wordpress.com        http://lyvinthenet.wordpress.com/
# 1    artificialintelligencemania.com  http://artificialintelligencemania.com/
# 2               jhrogue.blogspot.com             http://jhrogue.blogspot.com/
# 3                       teach-ict.co                     http://teach-ict.co/
# 4                        bbb2022.com                      http://bbb2022.com/
# ..                               ...                                      ...
# 995                  dieseltykes.com                  http://dieseltykes.com/
# 996                measureaustin.org                http://measureaustin.org/
# 997                baylaurelfund.com                http://baylaurelfund.com/
# 998                   bearracuda.com                   http://bearracuda.com/
# 999                candymanmovie.com                http://candymanmovie.com/
#
#                            clean_url
# 0          lyvinthenet.wordpress.com
# 1    artificialintelligencemania.com
# 2               jhrogue.blogspot.com
# 3                       teach-ict.co
# 4                        bbb2022.com
# ..                               ...
# 995                  dieseltykes.com
# 996                measureaustin.org
# 997                baylaurelfund.com
# 998                   bearracuda.com
# 999                candymanmovie.com
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Make the comparison between the two dataframes using `clean_url` (in MediaCloud sources) and `canonical domain` (in LNI sources)
# When we make this comparison we will loose all sources from patch.com, thus we need to make another comparison between the sources that are coming from patch.com using `clean_url` only

# %%
mediacloud_urls = set(mediacloud_df['clean_url'])
mask = ~lni_df['canonical_domain'].isin(mediacloud_urls)
filtered_df = lni_df[mask].copy()
filtered_df.shape
# Out:
# (2222, 10)

# %% [markdown]
# #### Get sources from "patch.com", these need special processing, if we use canonical domain for comparison then we will loose a lot of data as all sources will have one domain i.e. patch.com

# %%
patch_lni_df = lni_df[lni_df['url'].str.contains('patch.com/', na=False)]
patch_lni_df.shape
# Out:
# (545, 10)

# %%
patch_mediacloud_df = mediacloud_df[mediacloud_df['homepage'].str.contains('://patch.com', na=False)]
patch_mediacloud_df.shape
# Out:
# (271, 5)

# %%
mediacloud_urls = set(patch_mediacloud_df['clean_url'])
mask = ~_patch_lni_df['clean_url'].isin(mediacloud_urls)
_filtered_df = patch_lni_df[mask].copy()
_filtered_df
# Out:
#         id state          county                        media_name  \
# 320    321    MD       Baltimore                     Arbutus Times
# 359    360    IL            Lake                Highland Park News
# 390    391    IL            Cook                     Winnetka Talk
# 416    417    PA      Montgomery         Phoenix Reporter and Item
# 500    501    NY          Nassau              Port Washington News
# ...    ...   ...             ...                               ...
# 6981  6982    CT         Capitol                Patch Wethersfield
# 6982  6983    CT         Capitol                     Patch Windsor
# 6983  6984    CT         Capitol  Patch Windsor Locks-East Windsor
# 6984  6985    MD  Baltimore City                   Patch Baltimore
# 7058  7059    PA      Montgomery                Metro Chinese News
#
#           media_type  year_loaded   fips  \
# 320        Newspaper         2024  24005
# 359        Newspaper         2024  17097
# 390        Newspaper         2024  17031
# 416        Newspaper         2024  42091
# 500        Newspaper         2024  36059
# ...              ...          ...    ...
# 6981   Network Sites         2024   9110
# 6982   Network Sites         2024   9110
# 6983   Network Sites         2024   9110
# 6984   Network Sites         2024  24510
# 7058  Ethnic Outlets         2024  42091
#
#                                               url canonical_domain  \
# 320                    patch.com/maryland/arbutus        patch.com
# 359               patch.com/illinois/highlandpark        patch.com
# 390                   patch.com/illinois/winnetka        patch.com
# 416   patch.com/pennsylvania/lansdale/police-fire        patch.com
# 500             patch.com/new-york/portwashington        patch.com
# ...                                           ...              ...
# 6981    patch.com/connecticut/wethersfield?page=2        patch.com
# 6982                patch.com/connecticut/windsor        patch.com
# 6983           patch.com/connecticut/windsorlocks        patch.com
# 6984                 patch.com/maryland/baltimore        patch.com
# 7058  patch.com/pennsylvania/lansdale/police-fire        patch.com
#
#                                         clean_url
# 320                    patch.com/maryland/arbutus
# 359               patch.com/illinois/highlandpark
# 390                   patch.com/illinois/winnetka
# 416   patch.com/pennsylvania/lansdale/police-fire
# 500             patch.com/new-york/portwashington
# ...                                           ...
# 6981    patch.com/connecticut/wethersfield?page=2
# 6982                patch.com/connecticut/windsor
# 6983           patch.com/connecticut/windsorlocks
# 6984                 patch.com/maryland/baltimore
# 7058  patch.com/pennsylvania/lansdale/police-fire
#
# [399 rows x 10 columns]

# %% [markdown]
# ### Export the content to CSV

# %% [markdown]
# #### Exporting sources from LNI not present in the MediaCloud directory

# %%
df_combined = pd.concat([_filtered_df, filtered_df], ignore_index=True)
# Dropping any duplicate sources
df_combined = df_combined.drop_duplicates(subset='clean_url', keep='first')
df_combined.to_csv('tmp/sources_in_lni_not_in_mc_updated.csv', index=False)
df_combined.shape
# Out:
# (2462, 10)

# %% [markdown]
# #### Exporting all sources from LNI

# %%
lni_df.head()
# Out:
#    id state      county                  media_name media_type  year_loaded  \
# 0   1    VA  Washington  ADJ Bristol Herald Courier  Newspaper         2024
# 1   2    VA     Augusta         ADJ The News Leader  Newspaper         2024
# 2   3    VA     Augusta      ADJ Augusta Free Press  Newspaper         2024
# 3   4    NC     Madison    News-Record and Sentinel  Newspaper         2024
# 4   5    WI        Wood     Marshfield News-Herald   Newspaper         2024
#
#     fips                                                url  \
# 0  51191                                  heraldcourier.com
# 1  51015                                 www.newsleader.com
# 2  51015  augustafreepress.com/news/sheriff-20k-in-coins...
# 3  37115  www.citizen-times.com/local/news-record-and-se...
# 4  55141                       www.marshfieldnewsherald.com
#
#            canonical_domain                                          clean_url
# 0         heraldcourier.com                                  heraldcourier.com
# 1            newsleader.com                                     newsleader.com
# 2      augustafreepress.com  augustafreepress.com/news/sheriff-20k-in-coins...
# 3         citizen-times.com   citizen-times.com/local/news-record-and-sentinel
# 4  marshfieldnewsherald.com                           marshfieldnewsherald.com
