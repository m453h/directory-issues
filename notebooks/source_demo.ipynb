# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
from pathlib import Path
import importlib
import random

# %pip install -q -e  ../. 

from directory_issues import Source
import mediacloud.api

token = "YOUR_TOKEN_HERE"
mc_dir = mediacloud.api.DirectoryApi(token)
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Here, just grab a sample of sources, just check it out. 
sources_with_url_search_strings = []

more_sources = True
offset = 0
limit=100000
while more_sources and len(sources_with_url_search_strings) < 200:
    
    resp = mc_dir.source_list(limit = limit, offset=offset)
    matches = [r for r in resp["results"] if r["url_search_string"] is not None]
    S = [Source(r) for r in matches]
    for s in S:
        print(s)
        s.find_issues()
    sources_with_url_search_strings.extend(S)
    print(len(sources_with_url_search_strings))
    if resp["next"] is not None:
        offset += limit
    else:
        more_sources = False
# Out:
# Source(indiatimes.com, http://timesofindia.indiatimes.com/)
# Source(ctvnews.ca, http://bc.ctvnews.ca/)
# Source(theguardian.com, https://www.theguardian.com/us)
# Source(intoday.in, http://indiatoday.intoday.in/#spider)
# Source(cbslocal.com, https://www.cbsnews.com/boston/)
# Source(forward.com, http://forward.com)
# Source(bizjournals.com, http://www.bizjournals.com/boston)
# Source(uol.com.br, http://www.folha.uol.com.br/)
# Source(iol.co.za, http://www.iol.co.za/the-star)
# Source(cbslocal.com, http://sanfrancisco.cbslocal.com)
# Source(bizjournals.com, http://www.bizjournals.com/sanfrancisco/)
# Source(bdlive.co.za, http://www.bdlive.co.za/)
# Source(ctvnews.ca, http://regina.ctvnews.ca/)
# Source(ctvnews.ca, http://windsor.ctvnews.ca/)
# Source(news12.com, http://connecticut.news12.com/)
# Source(nation.co.ke, http://nairobinews.nation.co.ke)
# Source(herald-dispatch.com, https://www.herald-dispatch.com)
# Source(ahram.org.eg, http://hebdo.ahram.org.eg/)
# Source(france24.com, http://www.france24.com/en/)
# Source(asahi.com, http://www.asahi.com/english/)
# Source(msk.ru, http://www.echo.msk.ru)
# Source(cbslocal.com, http://newyork.cbslocal.com)
# Source(india.com, http://zeenews.india.com)
# Source(cbslocal.com, http://losangeles.cbslocal.com)
# Source(cbslocal.com, http://philadelphia.cbslocal.com)
# Source(cbslocal.com, http://denver.cbslocal.com)
# Source(ria.ru, http://en.ria.ru/#spider)
# Source(people.com.cn, http://english.people.com.cn/)
# Source(junkee.com, http://junkee.com/#spider)
# Source(theguardian.com, http://www.theguardian.com/uk/)
# Source(cbslocal.com, http://dfw.cbslocal.com/)
# Source(allafrica.com, http://allafrica.com/kenya/)
# Source(pnn.ps, http://english.pnn.ps/)
# Source(khaama.com, http://www.khaama.com/#spider)
# Source(cbslocal.com, http://detroit.cbslocal.com)
# Source(cbslocal.com, http://chicago.cbslocal.com#spider)
# Source(cbslocal.com, http://miami.cbslocal.com#spider)
# Source(cbslocal.com, http://baltimore.cbslocal.com)
# Source(cbslocal.com, http://lasvegas.cbslocal.com#spider)
# Source(cbslocal.com, http://sacramento.cbslocal.com#spider)
# Source(bbc.co.uk, http://www.bbc.co.uk/arabic/)
# Source(corriere.it, http://www.corriere.it/english/)
# Source(vietnamnet.vn, http://english.vietnamnet.vn/)
# Source(trend.az, http://en.trend.az/)
# Source(streetsblog.org, http://nyc.streetsblog.org/)
# Source(hellomagazine.com, http://ca.hellomagazine.com/)
# Source(bizjournals.com, http://assets.bizjournals.com/rss/feed/reporter/Annlee+Ellingson/losangeles)
# Source(streetsblog.org, http://denver.streetsblog.org/)
# Source(bizjournals.com, http://www.bizjournals.com/boston/?t=1494343666)
# Source(mashable.com, http://in.mashable.com/)
# Source(citynews.ca, http://montreal.citynews.ca/)
# Source(dailyvoice.com/new-york/scarsdale, https://dailyvoice.com/new-york/scarsdale/)
# Source(donga.com, http://english.donga.com/)
# Source(yahoo.com, https://uk.movies.yahoo.com/)
# Source(southwales-eveningpost.co.uk, http://southwales-eveningpost.co.uk/)
# Source(qq.com, http://weixin.qq.com/)
# Source(ria.ru, http://de.ria.ru/)
# Source(ria.ru, http://sp.ria.ru/)
# Source(ieee.org, http://spectrum.ieee.org)
# Source(bbc.co.uk, http://www.bbc.co.uk/zhongwen/simp/)
# Source(bmj.com, http://www.bmj.com#spider)
# Source(aif.ru, http://kuban.aif.ru/)
# Source(aol.com, http://news.aol.com/)
# Source(ria.ru, http://ria.ru/#spider)
# Source(bashinform.ru, http://www.bashinform.ru/#spider)
# Source(bbc.co.uk, http://www.bbc.co.uk/mundo/)
# Source(bbc.co.uk, http://www.bbc.co.uk/russian/)
# Source(eater.com, http://ny.eater.com/#spider)
# Source(thegospelcoalition.org, http://thegospelcoalition.org/#spider)
# Source(corriere.it, http://27esimaora.corriere.it/)
# Source(joins.com, http://koreajoongangdaily.joins.com/#spider)
# Source(chinausfocus.com, http://www.chinausfocus.com/#spider)
# Source(gobo.com, https://g1.globo.com/ba/bahia/)
# Source(elpais.com, https://elpais.com/chile/)
# Source(ElPais.com, https://elpais.com/america-colombia/)
# Source(elpais.com, https://elpais.com/argentina/)
# Source(elpais.com, https://elpais.com/america-colombia)
# Source(yahoo.com, http://uk.style.yahoo.com/)
# Source(curbed.com, http://boston.curbed.com/)
# Source(theepochtimes.com, http://fr.theepochtimes.com/)
# Source(infowars.com, http://europe.infowars.com/)
# Source(bbc.com, https://www.bbc.com/news/world/africa)
# Source(uol.com.br, https://tnonline.uol.com.br)
# Source(suffolktimes.timesreview.com, http://suffolktimes.timesreview.com)
# Source(dailyvoice.com, dailyvoice.com/new-york/scarsdale)
# Source(koreadaily.com, http://www.koreadaily.com/index_local_branch.html?branch=NY)
# Source(bizjournals.com, http://partners.bizjournals.com/)
# 240

# %%
from IPython.display import HTML
HTML(random.choice(sources_with_url_search_strings).render_template())
# Out:
# <body>
# <h1>Business First : 04:13PM on October 31, 2024</h1>
#
# <a href='https://search.mediacloud.org/sources/661021'> Business First </a>
#
#
# 	<div>
# 		<h2> url_search_string issues </h2>
# 		<ul>
#
# 			<li> url_search_string does not end in '*'. Add a postfix wildcard. </li>
#
# 		</ul>
#
#
# </body>

# %%
sources = sources_with_url_search_strings

# %%
sources_with_issues = [s for s in sources if len(s.issues) != 0]

# %%
len(sources_with_issues)
# Out:
# 194

# %%
sources_with_issues[5].issues
# Out:
# [{'issue_name': 'USS-*-Postfix',
#   'template': "url_search_string does not end in '*'. Add a postfix wildcard.",
#   'tags': ['url_search_string']}]

# %% [raw]
# mc_dir.
