# %%
# %pip install -q -e  ../. 
import os
os.environ["MC_API_TOKEN"]="BYO"

from directory_issues import Collection, Source
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# zammad_token='' zammad_url='https://support.mediacloud.org/api/v1/' default_zammad_group='Users' default_zammad_user='Directory Detective' default_zammad_email='support@mediacloud.org'

# %%
source = Source.from_id(1, skip_feeds=False, skip_volume=False)

# %%
source
# Out:
# Source(nytimes.com, http://nytimes.com)

# %%
source.feed_list
# Out:
# [Feed(15:NYT > Dining & Wine),
#  Feed(421563:Opinionator &#187; &#187; Bedside),
#  Feed(2463485:None),
#  Feed(2463486:None),
#  Feed(2463487:None),
#  Feed(49642:City Room),
#  Feed(49641:Carpetbagger),
#  Feed(49705:Opinionator &#187; &#187; Linda Greenhouse),
#  Feed(421548:Opinionator &#187; &#187; Things I Saw),
#  Feed(421559:Opinionator &#187; &#187; Disunion),
#  Feed(1761801:NYT > Most Popular),
#  Feed(3:Essential Knowledge of the Day),
#  Feed(49635:ArtsBeat),
#  Feed(49702:Opinionator &#187; &#187; Doug Glanville),
#  Feed(49696:Nicholas Kristof),
#  Feed(5:NYT > Americas),
#  Feed(49651:Gambit),
#  Feed(16:NYT > Education),
#  Feed(1761819:NYT > Business),
#  Feed(2391397:NYT > Jamelle Bouie),
#  Feed(44:NYT > Pro Football),
#  Feed(62:NYT > Washington),
#  Feed(1761825:NYT > World > Africa),
#  Feed(2291148:NYT > The Upshot),
#  Feed(24:NYT > Hockey),
#  Feed(49720:Ross Douthat),
#  Feed(421554:Opinionator &#187; &#187; Schooling),
# ...

# %%
source.find_issues()

# %%
source.feed_issues
# Out:
# [Feed(15:NYT > Dining & Wine),
#  Feed(421563:Opinionator &#187; &#187; Bedside),
#  Feed(2463485:None),
#  Feed(2463486:None),
#  Feed(2463487:None),
#  Feed(49642:City Room),
#  Feed(49641:Carpetbagger),
#  Feed(49705:Opinionator &#187; &#187; Linda Greenhouse),
#  Feed(421548:Opinionator &#187; &#187; Things I Saw),
#  Feed(421559:Opinionator &#187; &#187; Disunion),
#  Feed(1761801:NYT > Most Popular),
#  Feed(3:Essential Knowledge of the Day),
#  Feed(49635:ArtsBeat),
#  Feed(49702:Opinionator &#187; &#187; Doug Glanville),
#  Feed(49696:Nicholas Kristof),
#  Feed(5:NYT > Americas),
#  Feed(49651:Gambit),
#  Feed(16:NYT > Education),
#  Feed(1761819:NYT > Business),
#  Feed(2391397:NYT > Jamelle Bouie),
#  Feed(44:NYT > Pro Football),
#  Feed(62:NYT > Washington),
#  Feed(1761825:NYT > World > Africa),
#  Feed(2291148:NYT > The Upshot),
#  Feed(24:NYT > Hockey),
#  Feed(49720:Ross Douthat),
#  Feed(421554:Opinionator &#187; &#187; Schooling),
# ...

# %%
source.source_volume.recent_histogram
# Out:
# [{'date': datetime.date(2024, 10, 26),
#   'total_count': 102,
#   'count': 102,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 10, 27),
#   'total_count': 139,
#   'count': 139,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 10, 28),
#   'total_count': 186,
#   'count': 186,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 10, 29),
#   'total_count': 166,
#   'count': 166,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 10, 30),
#   'total_count': 176,
#   'count': 176,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 10, 31),
#   'total_count': 241,
#   'count': 241,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 11, 1),
#   'total_count': 176,
#   'count': 176,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 11, 2),
#   'total_count': 99,
#   'count': 99,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 11, 3),
#   'total_count': 141,
#   'count': 141,
#   'ratio': 1.0},
#  {'date': datetime.date(2024, 11, 4),
#   'total_count': 185,
#   'count': 185,
# ...

# %%
len(source.feed_list)
# Out:
# 278

# %%
len(source.feed_issues)
# Out:
# 278
